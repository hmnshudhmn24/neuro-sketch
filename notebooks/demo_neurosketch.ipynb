# %% [markdown]
# # NEUROSKETCH demo
# Generate a synthetic EEG, map it to a prompt, and (optionally) run Stable Diffusion to create an image.

# %%
# !python synth_eeg.py
# !python eeg_to_prompt.py --eeg examples/sample_eeg.csv
